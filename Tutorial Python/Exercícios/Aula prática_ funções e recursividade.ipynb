# %% [markdown]
# ## Problemas sobre funções e recursividade
# Os problemas seguir estão relacionados com o conteúdo das Aulas:
# * [Funções, variáveis locais e globais](https://colab.research.google.com/drive/1pKYusu5ipq3RGizsLLbRUiUvIXK3rOom?usp=sharing)
# * [Funções e recursividade](https://colab.research.google.com/drive/1XTsCKqjRS7sto_mEzXwHUX6b65jWtPat?usp=sharing)

# %% [markdown]
# **Problema 1.**. Escreva uma função chamada `converte_temperatura` que recebe uma temperatura em graus Celsius como parâmetro e retorna o valor equivalente em graus Fahrenheit. A fórmula de conversão é: `Fahrenheit = (Celsius * 9/5) + 32`.

# %%
#código aqui

# %% [markdown]
# **Problema 2**. Implemente uma função chamada `calcula_media` que recebe uma lista de números como parâmetro e retorna a média aritmética desses números.

# %%
#código aqui

# %%
# Out:
# 3.25

# %% [markdown]
# **Problema 3**. Crie uma função chamada `calcula_juros_compostos` que recebe três parâmetros: o valor inicial aplicado, a taxa de juros anual e o período de tempo em anos. A função deve calcular o montante final após o período de tempo informado, considerando juros compostos.  A fórmula para o cálculo dos juros compostos é: Montante Final = Valor Inicial * (1 + Taxa de Juros)^Período.

# %%
#código

# %%
# Out:
# 1123.6000000000001

# %% [markdown]
# **Problema 4**. Considere o seguinte código:
#
#
# ```python
# valor_global = 10
#
# def multiplica_por_valor_global(numero):
#     resultado = numero * valor_global
#     return resultado
#
# valor = 5
# resultado = multiplica_por_valor_global(valor)
# print("O resultado da multiplicação é:", resultado)
# ```
# Pergunta: Qual será o resultado impresso?
#
# a) 10
#
# b) 15
#
# c) 25
#
# d) 50

# %% [markdown]
# **Problema 5**. Considere o seguinte código:
#
#
#
# ```python
# def calcula_area_retangulo(largura, altura):
#     area = largura * altura
#     return area
#
# largura = 5
#
# def calcula_perimetro_retangulo():
#     perimetro = 2 * (largura + altura)
#     return perimetro
#
# altura = 3
# resultado_area = calcula_area_retangulo(largura, altura)
# resultado_perimetro = calcula_perimetro_retangulo()
#
# print("A área do retângulo é:", resultado_area)
# print("O perímetro do retângulo é:", resultado_perimetro)
# ```
#
# Pergunta: Qual será o resultado impresso no console?
#
# a) A área do retângulo é: 15, O perímetro do retângulo é: 16
#
# b) A área do retângulo é: 15, O perímetro do retângulo é: 26
#
# c) A área do retângulo é: 15, O perímetro do retângulo é: 30
#
# d) Erro de execução

# %% [markdown]
# **Problema 6**. Implemente uma função recursiva para calcular a soma dos dígitos de um número inteiro.

# %%
#código aqui

# %% [markdown]
# **Problema 7**. Calcule o resultado da operação de potenciação utilizando uma função recursiva.

# %%
#código aqui

# %% [markdown]
# **Problema 8**. Implemente uma função recursiva para encontrar o valor mínimo em uma lista de números.

# %%
#código aqui

# %%
# Out:
# 2

# %% [markdown]
# **Problema 9**. Implemente uma função recursiva para calcular o produto de dois números inteiros usando apenas a soma.

# %%
#código aqui

# %% [markdown]
# **Problema 10**. Calcule a soma de todos os elementos em uma lista utilizando uma função recursiva.

# %%
#código aqui

# %% [markdown]
# **Problemas 11**. Implemente uma função recursiva para encontrar o maior elemento em uma lista de números.

# %%
#código aqui
