# %% [markdown]
# ## Exercícios: números e operações matemáticas
#
# Os problemas seguir estão relacionados com o conteúdo da Aula:
#
# * [Números e operações matemáticas](https://colab.research.google.com/drive/12hKxMwS3GQeWZLNOuelspFL_tJ9qDO0a?usp=sharing)

# %% [markdown]
# **Problema 1**. Calcule a área de um retângulo com base e altura informadas pelo usuário.

# %%
# código aqui

# %% [markdown]
# **Problema 2**. Calcule a média aritmética de três números informados pelo usuário.

# %%
# código aqui

# %% [markdown]
# **Problema 3**. Calcule o seno de um ângulo em radianos. O ângulo deve ser fornecido  pelo usuário em graus.

# %%
# código aqui
import math

# %% [markdown]
# **Problema 4**. Troque o valor de duas variáveis sem utilizar uma terceira variável.

# %%
# código aqui

# %% [markdown]
# **Problema 5**. Multiplique o valor de uma variável por 2 e armazene o resultado na mesma variável.

# %%
# código aqui

# %% [markdown]
# **Problema 6**. Crie uma função lambda para calcular o dobro de um número.

# %%
# código aqui

# %% [markdown]
# **Problema 7**. Crie uma função lambda para calcular a média aritmética de três números.

# %%
# código aqui

# %% [markdown]
# **Problema 8**. Calcule o resultado de uma expressão matemática que envolve operações com ponto flutuante.
#
# O valor esperado do cálculo da expressão
# ```python
# 1.1 - 1.0 - 0.1
# ```
# é `0.0`.
#
# Entretanto, a saída é
#
#
# ```python
# 8.326672684688674e-17
# ```
#
#
# modifique a expressão de modo a obter o valor esperado.

# %%
# código aqui
